# %% [markdown]
# ![Screenshot 2025-08-12 at 7.46.29 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Topics
#
#
#
# ---
#
# *   Basic Data Types
# *   Print Statements
# *   Input Statements
# *   Arthemtic
# *   Comparison Operators
# *   Loops
# *   Control Conditions
# *   Advanced Data Types

# %% [markdown]
# # Data Types
#
# ---

# %%
#String
'Hello'

#Integer(Int)
5

#Float
3.14

#Boolean
True

False
# Out:
# False

# %%
Day = 'Thursday'

y = 5

pi = 3.1415926535

T = True

# %% [markdown]
# addition assignment

# %%
a = 9

a += 1

a
# Out:
# 10

# %% [markdown]
# subtraction assignment

# %%
b = 9

b -= 1

b
# Out:
# 8

# %% [markdown]
# here is how we check data types

# %%
type('Word')
# Out:
# str

# %%
type(5)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %% [markdown]
# # Print Statements
#
#
#
# ---

# %%
#Printing string
print('hello world')

#Priting Int
print(5)

print(y)

#Printing Floats
print(3.14)

print(pi)
# Out:
# hello world
# 5
# 5
# 3.14
# 3.1415926535

# %%
#No difference between single and double quotes
print("Hello, world")
print('Hello, world')
# Out:
# Hello, world
# Hello, world

# %%
name = 'John'

print('Hi my name is', name)
# Out:
# Hi my name is John

# %%
alpha = 'abc'
bet = 'def'
print(alpha+bet)
# Out:
# abcdef

# %% [markdown]
# When trying to concatenate a string and a number in Python you will get an error

# %%
sentence = 'I am'
age = 5
#print(sentence + age) # gives type error

#instead we can use the comnma
print(sentence,age)
# Out:
# i am  5

# %% [markdown]
# # Inputing Values
#
# ---

# %%
day = input('What is todays day? ')

print('Today is', day)
# Out:
# What is todays day? Thursday
# Today is Thursday

# %% [markdown]
# # Arthemtic
#
# ---
#
# ![1_XRz6kN1VX6S1qRCr4GlUgw.png](data:image/png;base64,...)

# %%
x = 4
y = 8

print(y+x)
print(y-x)
print(y*x)
print(y/x)
# Out:
# 12
# 4
# 32
# 2.0

# %%
#Quotient or floor division
print ('The quotient of 20 divided by 3 is', 20//3)
# Out:
# The quotient of 20 divided by 3 is 6

# %%
#Modulus
print ('The remainder of 10 divided by 6 is', 10%6)
# Out:
# The remainder of 10 divided by 6 is 4

# %%
#Exponentiational
print('4 to the power of 3 is', 4**3)
# Out:
# 4 to the power of 3 is 64

# %% [markdown]
# # Comparison Operators
#
# ---

# %%
#Less than
print (5 < 10)

#Greater than
print(5 > 10)

#Equals
print(5 == 5)

#Not equals
print(5 != 5)

#Less than or equals
print(5 <= 10)

#Greater than or equals
print(5 >= 10)
# Out:
# True
# False
# True
# False
# True
# False

# %% [markdown]
# # Loops
#
# ---
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A **for loop** is used for iterating over a sequence or repeating something a set number of times.

# %%
for i in range(5): #(starting point, ending point(not inclusive))
  print(i)  #beware of the indentation
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,11):
  print('hello world')
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A **while loop** we is used to execute a set of statements as long as a condition is true

# %%
i=1
while i<9:
  print(i)  #beware of the indentation
  i += 1

print('we are out of the while loop')
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# we are out of the while loop

# %%
# Calculate the sum of numbers from 1 to 10
total = 0
num = 1
while num <= 10:
    total += num # gives us total = 1 (on the first loop)
    num += 1 #num= num +1
print('The sum of the numbers from 1 to 10 is', total)
# Out:
# The sum of the numbers from 1 to 10 is 55

# %%
# How do I print out average?
average= total/10
print('average is', average)
# Out:
# average is 5.5

# %% [markdown]
# # Control conditions

# %% [markdown]
# **if** statements executes a block of code only if a specified condition is true.

# %%
x = 300
y = 200

if(x >= y):
  print('x is greater than or equals to y') #beware of the indentation

if(x <= y):
  print('x is not greater than or equals to y')
# Out:
# x is greater than or equals to y

# %% [markdown]
# **else** statements catches anything which isn't caught by the preceding conditions

# %%
y=8
if (y==7):
  print('y is seven')
else:
  print('y is not 7, y is', y)
# Out:
# y is not 7, y is 8

# %% [markdown]
# **elif** statments are used when a  previous conditions is not true to then try another condition

# %%
x=10

if (x==5):
  print('x is five')
elif (x==8):
  print('x is eight')
elif(x==10):
  print('x is ten')
else:
  print('x is not 5 nor 8 nor 10')
# Out:
# x is ten

# %% [markdown]
# **and** is used to combine conditional statements where both conditons are true

# %%
a = 200
b = 33
c = 500
if a > b and c > a:
  print("Both conditions are True")
# Out:
# Both conditions are True

# %% [markdown]
# **or** is used to combine conditional statements where at least one condition is true

# %%
a = 200
b = 33
c = 500
if a > b or a > c:
  print("At least one of the conditions is True")
# Out:
# At least one of the conditions is True

# %% [markdown]
# **not** is used to reverse ae conditional statement

# %%
a = 33
b = 200
if not a > b:
  print("a is NOT greater than b")
# Out:
# a is NOT greater than b

# %%
decision = input("Truth or Dare:")

if (decision=="Truth"):
  print('Tell a story')
elif (decision=="Dare"):
  print('I dare you to follow the MLDS instagram')
else:
  print('invalid')
# Out:
# Truth or Dare:Dare
# I dare you to follow the MLDS instagram

# %% [markdown]
# now try to combine for-loop with if-else statement to find out if a number is even or odd

# %%
for i in range (1,11):
  if (i%2==0):
    print (i,' is even number')
  else:
    print(i,' is odd number')
# Out:
# 1  is odd number
# 2  is even number
# 3  is odd number
# 4  is even number
# 5  is odd number
# 6  is even number
# 7  is odd number
# 8  is even number
# 9  is odd number
# 10  is even number

# %% [markdown]
# # Advanced data types

# %% [markdown]
# **Lists** are used to store multiple items in a single variable
#
# Lists are:
#
# *   Ordered
# *   Mutable(Elements can be changed)
# *   Allow for Duplicate
# *   Can store elements of different data types
# *   Indexed (starting from 0 for the first element and -1 for the last)

# %%
#A list with various data types
mixed_list = ['apples', 1 , 2+2 , 3.14, True]
print(mixed_list)
# Out:
# ['apples', 1, 4, 3.14, True]

# %%
# Creating a list
my_list = [1, 2, 3, 4, 5]
print(my_list)

#Indexing
print(my_list[0])
print(my_list[-1])
# Out:
# [1, 2, 3, 4, 5]
# 1
# 5

# %%
#Indexing multiple elements
print(my_list[0:3])
# Out:
# [1, 2, 3]

# %%
#Duplcating list

copy_list = my_list.copy()
print(copy_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Modifying elements
my_list[0] = 10
print(my_list)
# Out:
# [10, 2, 3, 4, 5]

# %% [markdown]
# **len** is used to get the length of a list

# %%
len(my_list)
# Out:
# 5

# %%
# Appending elements
my_list.append(6)
print(my_list)

len(my_list)
# Out:
# [10, 2, 3, 4, 5, 6]
# 6

# %%
# Removing elements
my_list.remove(3)
print(my_list)

len(my_list)
# Out:
# [10, 2, 4, 5, 6]
# 5

# %%
#Lets compare the orignal list to the changed list

print(copy_list)
print(my_list)
# Out:
# [1, 2, 3, 4, 5]
# [10, 2, 4, 5, 6]

# %% [markdown]
# Notice how they are the same even though we did not change the copied list, that is because we created what is know as a shallow copy
#
# A shallow copy makes a new object but only copies references to the inner objects, so changes to shared inner objects affect both copies
#
# A deep copy makes a completely independent clone of the object and all its inner objects, so changes in one do not affect the other

# %% [markdown]
# **Tuples** are very similar to lists the main difference is that they are **immutable** meaning they can not be changed

# %%
# Creating a tuple
my_tuple = (1, 2, 3, 4, 5)

len(my_tuple)
# Out:
# 5

# %%
x=my_tuple[0]

# Accessing elements
print(x)
# Out:
# 1

# %%
# Tuples are immutable - this would raise an error:
#my_tuple[0] = 10

# %% [markdown]
# **Sets** are also like lists however they are unordered, unchangeable, and can not be copied

# %%
thisset = {"apple", "banana", "cherry", "apple"}

print(thisset)
# Out:
# {'cherry', 'apple', 'banana'}

# %% [markdown]
# Combine List with For Loop

# %%
# Define a list
fruits = ["apple", "banana", "cherry", "orange"]
print(fruits)

# Iterate over each item in the list and print them
for fruit in fruits:
  print(fruit)
# Out:
# ['apple', 'banana', 'cherry', 'orange']
# apple
# banana
# cherry
# orange

# %%
# Iterating over a tuple
my_tuple = (1, 2, 3, 4, 5)
for item in my_tuple:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Iterating over a set
my_set = {1, 2, 3, 4, 5}
for item in my_set:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5
